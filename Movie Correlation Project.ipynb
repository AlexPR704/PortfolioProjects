# %%
# First let's import the packages

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# Now we need to read in the data
df = pd.read_csv(r"C:\Users\alexg\Downloads\movies.csv",encoding='latin1')

# %%
# Now let's take a look at the data

df.head()
# Out:
#        budget                                 company country       director  \
# 0   8000000.0           Columbia Pictures Corporation     USA     Rob Reiner
# 1  15000000.0                      Paramount Pictures     USA     Tony Scott
# 2  18500000.0  Twentieth Century Fox Film Corporation     USA  James Cameron
# 3   6000000.0                      Paramount Pictures     USA    John Hughes
# 4   9000000.0                      Paramount Pictures     USA  Howard Deutch
#
#        genre        gross                      name rating    released  \
# 0  Adventure   52287414.0               Stand by Me      R  1986-08-22
# 1     Action  179800601.0                   Top Gun     PG  1986-05-16
# 2     Action   85160248.0                    Aliens      R  1986-07-18
# 3     Comedy   70136369.0  Ferris Bueller's Day Off  PG-13  1986-06-11
# 4     Comedy   40471663.0            Pretty in Pink  PG-13  1986-02-28
#
#    runtime  score               star         writer  year
# 0       89    8.1        Wil Wheaton   Stephen King  1986
# 1      110    6.9         Tom Cruise       Jim Cash  1986
# 2      137    8.4   Sigourney Weaver  James Cameron  1986
# 3      103    7.8  Matthew Broderick    John Hughes  1986
# 4       96    6.8     Molly Ringwald    John Hughes  1986

# %%
# Checking for missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# budget - 0.0%
# company - 0.0%
# country - 0.0%
# director - 0.0%
# genre - 0.0%
# gross - 0.0%
# name - 0.0%
# rating - 0.0%
# released - 0.0%
# runtime - 0.0%
# score - 0.0%
# star - 0.0%
# writer - 0.0%
# year - 0.0%

# %%
# Data Types for the columns

df.dtypes
# Out:
# budget      float64
# company      object
# country      object
# director     object
# genre        object
# gross       float64
# name         object
# rating       object
# released     object
# runtime       int64
# score       float64
# star         object
# writer       object
# year          int64
# dtype: object

# %%
# Change data type of columns

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
df
# Out:
#         budget                                 company country  \
# 0      8000000           Columbia Pictures Corporation     USA
# 1     15000000                      Paramount Pictures     USA
# 2     18500000  Twentieth Century Fox Film Corporation     USA
# 3      6000000                      Paramount Pictures     USA
# 4      9000000                      Paramount Pictures     USA
# ...        ...                                     ...     ...
# 3095  28000000                            George Films      UK
# 3096  27500000                               Lionsgate     USA
# 3097  70000000               RatPac-Dune Entertainment     USA
# 3098  50000000                         New Line Cinema     USA
# 3099  30000000                FilmNation Entertainment     USA
#
#                      director      genre      gross                      name  \
# 0                  Rob Reiner  Adventure   52287414               Stand by Me
# 1                  Tony Scott     Action  179800601                   Top Gun
# 2               James Cameron     Action   85160248                    Aliens
# 3                 John Hughes     Comedy   70136369  Ferris Bueller's Day Off
# 4               Howard Deutch     Comedy   40471663            Pretty in Pink
# ...                       ...        ...        ...                       ...
# 3095              Brad Furman  Biography   15425870           The Infiltrator
# 3096                Dan Mazer     Comedy   35537564             Dirty Grandpa
# 3097         Nicholas Stoller  Animation   72655779                    Storks
# 3098  Rawson Marshall Thurber     Action  127440871      Central Intelligence
# 3099              Woody Allen     Comedy   11103205              Café Society
#
#      rating    released  runtime  score               star            writer  \
# 0         R  1986-08-22       89    8.1        Wil Wheaton      Stephen King
# 1        PG  1986-05-16      110    6.9         Tom Cruise          Jim Cash
# 2         R  1986-07-18      137    8.4   Sigourney Weaver     James Cameron
# 3     PG-13  1986-06-11      103    7.8  Matthew Broderick       John Hughes
# 4     PG-13  1986-02-28       96    6.8     Molly Ringwald       John Hughes
# ...     ...         ...      ...    ...                ...               ...
# 3095      R  2016-07-13      127    7.0     Bryan Cranston   Ellen Sue Brown
# 3096      R  2016-01-22      102    6.0     Robert De Niro     John Phillips
# 3097     PG  2016-09-23       87    6.8       Andy Samberg  Nicholas Stoller
# 3098  PG-13  2016-06-17      107    6.3     Dwayne Johnson    Ike Barinholtz
# 3099  PG-13  2016-08-05       96    6.7    Jesse Eisenberg       Woody Allen
#
#       year
# 0     1986
# 1     1986
# 2     1986
# 3     1986
# 4     1986
# ...    ...
# 3095  2016
# 3096  2016
# 3097  2016
# 3098  2016
# 3099  2016
#
# [3100 rows x 14 columns]

# %%
# corect year column

df['yearcorrect'] = df['released'].astype(str).str[:4]

# %%
df
# Out:
#         budget                                 company country  \
# 0      8000000           Columbia Pictures Corporation     USA
# 1     15000000                      Paramount Pictures     USA
# 2     18500000  Twentieth Century Fox Film Corporation     USA
# 3      6000000                      Paramount Pictures     USA
# 4      9000000                      Paramount Pictures     USA
# ...        ...                                     ...     ...
# 3095  28000000                            George Films      UK
# 3096  27500000                               Lionsgate     USA
# 3097  70000000               RatPac-Dune Entertainment     USA
# 3098  50000000                         New Line Cinema     USA
# 3099  30000000                FilmNation Entertainment     USA
#
#                      director      genre      gross                      name  \
# 0                  Rob Reiner  Adventure   52287414               Stand by Me
# 1                  Tony Scott     Action  179800601                   Top Gun
# 2               James Cameron     Action   85160248                    Aliens
# 3                 John Hughes     Comedy   70136369  Ferris Bueller's Day Off
# 4               Howard Deutch     Comedy   40471663            Pretty in Pink
# ...                       ...        ...        ...                       ...
# 3095              Brad Furman  Biography   15425870           The Infiltrator
# 3096                Dan Mazer     Comedy   35537564             Dirty Grandpa
# 3097         Nicholas Stoller  Animation   72655779                    Storks
# 3098  Rawson Marshall Thurber     Action  127440871      Central Intelligence
# 3099              Woody Allen     Comedy   11103205              Café Society
#
#      rating    released  runtime  score               star            writer  \
# 0         R  1986-08-22       89    8.1        Wil Wheaton      Stephen King
# 1        PG  1986-05-16      110    6.9         Tom Cruise          Jim Cash
# 2         R  1986-07-18      137    8.4   Sigourney Weaver     James Cameron
# 3     PG-13  1986-06-11      103    7.8  Matthew Broderick       John Hughes
# 4     PG-13  1986-02-28       96    6.8     Molly Ringwald       John Hughes
# ...     ...         ...      ...    ...                ...               ...
# 3095      R  2016-07-13      127    7.0     Bryan Cranston   Ellen Sue Brown
# 3096      R  2016-01-22      102    6.0     Robert De Niro     John Phillips
# 3097     PG  2016-09-23       87    6.8       Andy Samberg  Nicholas Stoller
# 3098  PG-13  2016-06-17      107    6.3     Dwayne Johnson    Ike Barinholtz
# 3099  PG-13  2016-08-05       96    6.7    Jesse Eisenberg       Woody Allen
#
#       year yearcorrect
# 0     1986        1986
# 1     1986        1986
# 2     1986        1986
# 3     1986        1986
# 4     1986        1986
# ...    ...         ...
# 3095  2016        2016
# 3096  2016        2016
# 3097  2016        2016
# 3098  2016        2016
# 3099  2016        2016
#
# [3100 rows x 15 columns]

# %%
# Order our data to see better

df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#          budget                                 company  country  \
# 2903  245000000                               Lucasfilm      USA
# 2302  237000000  Twentieth Century Fox Film Corporation       UK
# 1100  200000000  Twentieth Century Fox Film Corporation      USA
# 2916  150000000                      Universal Pictures      USA
# 2603  220000000                          Marvel Studios      USA
# ...         ...                                     ...      ...
# 2893          0                 Zentropa Entertainments  Denmark
# 1074          0                    Balboa Entertainment  Denmark
# 2311   47000000                          Pan Européenne  Belgium
# 1466    5000000               Copperheart Entertainment   Canada
# 1700    6000000                            Wiseau-Films      USA
#
#                   director   genre      gross                          name  \
# 2903           J.J. Abrams  Action  936662225  Star Wars: The Force Awakens
# 2302         James Cameron  Action  760507625                        Avatar
# 1100         James Cameron   Drama  658672302                       Titanic
# 2916       Colin Trevorrow  Action  652270625                Jurassic World
# 2603           Joss Whedon  Action  623357910                  The Avengers
# ...                    ...     ...        ...                           ...
# 2893      Kristian Levring   Drama       5000                  La salvación
# 1074  Nicolas Winding Refn   Crime       4440                        Pusher
# 2311      Jaco Van Dormael   Drama       3600                    Mr. Nobody
# 1466          John Fawcett   Drama       2554                         Feroz
# 1700          Tommy Wiseau   Drama       1800                      The Room
#
#          rating    released  runtime  score               star  \
# 2903      PG-13  2015-12-18      136    8.1       Daisy Ridley
# 2302      PG-13  2009-12-18      162    7.8    Sam Worthington
# 1100      PG-13  1997-12-19      194    7.8  Leonardo DiCaprio
# 2916      PG-13  2015-06-12      124    7.0        Chris Pratt
# 2603      PG-13  2012-05-04      143    8.1  Robert Downey Jr.
# ...         ...         ...      ...    ...                ...
# 2893          R  2015-02-27       92    6.7     Mads Mikkelsen
# 1074  NOT RATED  1996-08-30      105    7.4         Kim Bodnia
# 2311          R  2013-09-26      141    7.9         Jared Leto
# 1466    UNRATED  2001-05-18      108    6.8      Emily Perkins
# 1700          R  2004-03-03       99    3.6       Tommy Wiseau
#
#                     writer  year yearcorrect
# 2903       Lawrence Kasdan  2015        2015
# 2302         James Cameron  2009        2009
# 1100         James Cameron  1997        1997
# 2916            Rick Jaffa  2015        2015
# 2603           Joss Whedon  2012        2012
# ...                    ...   ...         ...
# 2893  Anders Thomas Jensen  2014        2015
# 1074             Jens Dahl  1996        1996
# 2311      Jaco Van Dormael  2009        2013
# 1466          Karen Walton  2000        2001
# 1700          Tommy Wiseau  2003        2004
#
# [3100 rows x 15 columns]

# %%
# Drop any duplicates

df.drop_duplicates()
# Out:
#         budget                                 company country  \
# 0      8000000           Columbia Pictures Corporation     USA
# 1     15000000                      Paramount Pictures     USA
# 2     18500000  Twentieth Century Fox Film Corporation     USA
# 3      6000000                      Paramount Pictures     USA
# 4      9000000                      Paramount Pictures     USA
# ...        ...                                     ...     ...
# 3095  28000000                            George Films      UK
# 3096  27500000                               Lionsgate     USA
# 3097  70000000               RatPac-Dune Entertainment     USA
# 3098  50000000                         New Line Cinema     USA
# 3099  30000000                FilmNation Entertainment     USA
#
#                      director      genre      gross                      name  \
# 0                  Rob Reiner  Adventure   52287414               Stand by Me
# 1                  Tony Scott     Action  179800601                   Top Gun
# 2               James Cameron     Action   85160248                    Aliens
# 3                 John Hughes     Comedy   70136369  Ferris Bueller's Day Off
# 4               Howard Deutch     Comedy   40471663            Pretty in Pink
# ...                       ...        ...        ...                       ...
# 3095              Brad Furman  Biography   15425870           The Infiltrator
# 3096                Dan Mazer     Comedy   35537564             Dirty Grandpa
# 3097         Nicholas Stoller  Animation   72655779                    Storks
# 3098  Rawson Marshall Thurber     Action  127440871      Central Intelligence
# 3099              Woody Allen     Comedy   11103205              Café Society
#
#      rating    released  runtime  score               star            writer  \
# 0         R  1986-08-22       89    8.1        Wil Wheaton      Stephen King
# 1        PG  1986-05-16      110    6.9         Tom Cruise          Jim Cash
# 2         R  1986-07-18      137    8.4   Sigourney Weaver     James Cameron
# 3     PG-13  1986-06-11      103    7.8  Matthew Broderick       John Hughes
# 4     PG-13  1986-02-28       96    6.8     Molly Ringwald       John Hughes
# ...     ...         ...      ...    ...                ...               ...
# 3095      R  2016-07-13      127    7.0     Bryan Cranston   Ellen Sue Brown
# 3096      R  2016-01-22      102    6.0     Robert De Niro     John Phillips
# 3097     PG  2016-09-23       87    6.8       Andy Samberg  Nicholas Stoller
# 3098  PG-13  2016-06-17      107    6.3     Dwayne Johnson    Ike Barinholtz
# 3099  PG-13  2016-08-05       96    6.7    Jesse Eisenberg       Woody Allen
#
#       year yearcorrect
# 0     1986        1986
# 1     1986        1986
# 2     1986        1986
# 3     1986        1986
# 4     1986        1986
# ...    ...         ...
# 3095  2016        2016
# 3096  2016        2016
# 3097  2016        2016
# 3098  2016        2016
# 3099  2016        2016
#
# [3100 rows x 15 columns]

# %%
# Scatter Plot with udget vs gross

plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs Gross Earnings')

plt.xlabel('Gross Earnings')

plt.ylabel('Budget for Film')
plt.show()

# %%
df.head()
# Out:
#      budget                                 company country       director  \
# 0   8000000           Columbia Pictures Corporation     USA     Rob Reiner
# 1  15000000                      Paramount Pictures     USA     Tony Scott
# 2  18500000  Twentieth Century Fox Film Corporation     USA  James Cameron
# 3   6000000                      Paramount Pictures     USA    John Hughes
# 4   9000000                      Paramount Pictures     USA  Howard Deutch
#
#        genre      gross                      name rating    released  runtime  \
# 0  Adventure   52287414               Stand by Me      R  1986-08-22       89
# 1     Action  179800601                   Top Gun     PG  1986-05-16      110
# 2     Action   85160248                    Aliens      R  1986-07-18      137
# 3     Comedy   70136369  Ferris Bueller's Day Off  PG-13  1986-06-11      103
# 4     Comedy   40471663            Pretty in Pink  PG-13  1986-02-28       96
#
#    score               star         writer  year yearcorrect
# 0    8.1        Wil Wheaton   Stephen King  1986        1986
# 1    6.9         Tom Cruise       Jim Cash  1986        1986
# 2    8.4   Sigourney Weaver  James Cameron  1986        1986
# 3    7.8  Matthew Broderick    John Hughes  1986        1986
# 4    6.8     Molly Ringwald    John Hughes  1986        1986

# %%
# Plot budget vs Gross using seaborn

sns.regplot(x="budget", y="gross", data=df, scatter_kws={"color": "red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# Looking at Correlation

df.corr(method='pearson') #pearson is default
# Out:
#            budget     gross   runtime     score      year
# budget   1.000000  0.682588  0.309652  0.019061  0.374904
# gross    0.682588  1.000000  0.238183  0.171825  0.246975
# runtime  0.309652  0.238183  1.000000  0.386864  0.127864
# score    0.019061  0.171825  0.386864  1.000000  0.109251
# year     0.374904  0.246975  0.127864  0.109251  1.000000

# %%
df.corr(method='kendall')
# Out:
#            budget     gross   runtime     score      year
# budget   1.000000  0.506346  0.215957 -0.024237  0.264997
# gross    0.506346  1.000000  0.149250  0.042364  0.161160
# runtime  0.215957  0.149250  1.000000  0.268800  0.100660
# score   -0.024237  0.042364  0.268800  1.000000  0.072388
# year     0.264997  0.161160  0.100660  0.072388  1.000000

# %%
df.corr(method='spearman')
# Out:
#            budget     gross   runtime     score      year
# budget   1.000000  0.688931  0.309472 -0.035468  0.374810
# gross    0.688931  1.000000  0.215672  0.058290  0.229680
# runtime  0.309472  0.215672  1.000000  0.381596  0.147590
# score   -0.035468  0.058290  0.381596  1.000000  0.105782
# year     0.374810  0.229680  0.147590  0.105782  1.000000

# %%
correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()

# %%
# Looking at Company

df.head()
# Out:
#      budget                                 company country       director  \
# 0   8000000           Columbia Pictures Corporation     USA     Rob Reiner
# 1  15000000                      Paramount Pictures     USA     Tony Scott
# 2  18500000  Twentieth Century Fox Film Corporation     USA  James Cameron
# 3   6000000                      Paramount Pictures     USA    John Hughes
# 4   9000000                      Paramount Pictures     USA  Howard Deutch
#
#        genre      gross                      name rating    released  runtime  \
# 0  Adventure   52287414               Stand by Me      R  1986-08-22       89
# 1     Action  179800601                   Top Gun     PG  1986-05-16      110
# 2     Action   85160248                    Aliens      R  1986-07-18      137
# 3     Comedy   70136369  Ferris Bueller's Day Off  PG-13  1986-06-11      103
# 4     Comedy   40471663            Pretty in Pink  PG-13  1986-02-28       96
#
#    score               star         writer  year yearcorrect
# 0    8.1        Wil Wheaton   Stephen King  1986        1986
# 1    6.9         Tom Cruise       Jim Cash  1986        1986
# 2    8.4   Sigourney Weaver  James Cameron  1986        1986
# 3    7.8  Matthew Broderick    John Hughes  1986        1986
# 4    6.8     Molly Ringwald    John Hughes  1986        1986

# %%
df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized
# Out:
#         budget  company  country  director  genre      gross  name  rating  \
# 0      8000000      257       37      1018      1   52287414  2133       6
# 1     15000000      668       37      1244      0  179800601  2861       4
# 2     18500000      837       37       478      0   85160248   133       6
# 3      6000000      668       37       597      4   70136369   827       5
# 4      9000000      668       37       449      4   40471663  1777       5
# ...        ...      ...      ...       ...    ...        ...   ...     ...
# 3095  28000000      425       36       127      3   15425870  2513       6
# 3096  27500000      565       37       224      4   35537564   640       6
# 3097  70000000      709       37       873      2   72655779  2166       4
# 3098  50000000      632       37       988      0  127440871   441       5
# 3099  30000000      380       37      1284      4   11103205   407       5
#
#       released  runtime  score  star  writer  year  yearcorrect
# 0           29       89    8.1  1150    1722  1986            0
# 1           16      110    6.9  1098     874  1986            0
# 2           24      137    8.4  1039     768  1986            0
# 3           19      103    7.8   767     928  1986            0
# 4            6       96    6.8   824     928  1986            0
# ...        ...      ...    ...   ...     ...   ...          ...
# 3095      1665      127    7.0   150     542  2016           30
# 3096      1642      102    6.0   945     944  2016           30
# 3097      1677       87    6.8    52    1362  2016           30
# 3098      1661      107    6.3   315     727  2016           30
# 3099      1670       96    6.7   556    1937  2016           30
#
# [3100 rows x 15 columns]

# %%
df
# Out:
#         budget  company  country  director  genre      gross  name  rating  \
# 0      8000000      257       37      1018      1   52287414  2133       6
# 1     15000000      668       37      1244      0  179800601  2861       4
# 2     18500000      837       37       478      0   85160248   133       6
# 3      6000000      668       37       597      4   70136369   827       5
# 4      9000000      668       37       449      4   40471663  1777       5
# ...        ...      ...      ...       ...    ...        ...   ...     ...
# 3095  28000000      425       36       127      3   15425870  2513       6
# 3096  27500000      565       37       224      4   35537564   640       6
# 3097  70000000      709       37       873      2   72655779  2166       4
# 3098  50000000      632       37       988      0  127440871   441       5
# 3099  30000000      380       37      1284      4   11103205   407       5
#
#       released  runtime  score  star  writer  year  yearcorrect
# 0           29       89    8.1  1150    1722  1986            0
# 1           16      110    6.9  1098     874  1986            0
# 2           24      137    8.4  1039     768  1986            0
# 3           19      103    7.8   767     928  1986            0
# 4            6       96    6.8   824     928  1986            0
# ...        ...      ...    ...   ...     ...   ...          ...
# 3095      1665      127    7.0   150     542  2016           30
# 3096      1642      102    6.0   945     944  2016           30
# 3097      1677       87    6.8    52    1362  2016           30
# 3098      1661      107    6.3   315     727  2016           30
# 3099      1670       96    6.7   556    1937  2016           30
#
# [3100 rows x 15 columns]

# %%
correlation_matrix = df_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()

# %%
df_numerized.corr()
# Out:
#                budget   company   country  director     genre     gross  \
# budget       1.000000  0.157083  0.118863  0.011052 -0.401052  0.682588
# company      0.157083  1.000000  0.061089 -0.018730 -0.083068  0.156013
# country      0.118863  0.061089  1.000000  0.010291 -0.062478  0.138064
# director     0.011052 -0.018730  0.010291  1.000000 -0.048337 -0.031221
# genre       -0.401052 -0.083068 -0.062478 -0.048337  1.000000 -0.263051
# gross        0.682588  0.156013  0.138064 -0.031221 -0.263051  1.000000
# name         0.051049  0.014947  0.034133 -0.004434  0.002989  0.039578
# rating      -0.171070 -0.083646  0.000015  0.030589  0.136055 -0.191666
# released     0.364690 -0.002053 -0.070944 -0.038601 -0.066830  0.237240
# runtime      0.309652  0.037491 -0.049398  0.018846 -0.061327  0.238183
# score        0.019061 -0.002730 -0.113568 -0.018591  0.067234  0.171825
# star        -0.016357  0.030054 -0.014146  0.001973  0.008380  0.013428
# writer      -0.031269  0.006527  0.035367  0.227905 -0.001986 -0.017184
# year         0.374904  0.001121 -0.057044 -0.037946 -0.072299  0.246975
# yearcorrect  0.361727 -0.002346 -0.072135 -0.038486 -0.065987  0.234971
#
#                  name    rating  released   runtime     score      star  \
# budget       0.051049 -0.171070  0.364690  0.309652  0.019061 -0.016357
# company      0.014947 -0.083646 -0.002053  0.037491 -0.002730  0.030054
# country      0.034133  0.000015 -0.070944 -0.049398 -0.113568 -0.014146
# director    -0.004434  0.030589 -0.038601  0.018846 -0.018591  0.001973
# genre        0.002989  0.136055 -0.066830 -0.061327  0.067234  0.008380
# gross        0.039578 -0.191666  0.237240  0.238183  0.171825  0.013428
# name         1.000000 -0.014934  0.029409  0.031283  0.011649  0.008144
# rating      -0.014934  1.000000  0.049616  0.153396  0.048781  0.004985
# released     0.029409  0.049616  1.000000  0.133181  0.120931 -0.037896
# runtime      0.031283  0.153396  0.133181  1.000000  0.386864 -0.007494
# score        0.011649  0.048781  0.120931  0.386864  1.000000 -0.006750
# star         0.008144  0.004985 -0.037896 -0.007494 -0.006750  1.000000
# writer       0.055729  0.017506 -0.021203 -0.020986  0.000293  0.027501
# year         0.028571  0.048356  0.996873  0.127864  0.109251 -0.039222
# yearcorrect  0.027662  0.051107  0.999434  0.130664  0.119861 -0.038432
#
#                writer      year  yearcorrect
# budget      -0.031269  0.374904     0.361727
# company      0.006527  0.001121    -0.002346
# country      0.035367 -0.057044    -0.072135
# director     0.227905 -0.037946    -0.038486
# genre       -0.001986 -0.072299    -0.065987
# gross       -0.017184  0.246975     0.234971
# name         0.055729  0.028571     0.027662
# rating       0.017506  0.048356     0.051107
# released    -0.021203  0.996873     0.999434
# runtime     -0.020986  0.127864     0.130664
# score        0.000293  0.109251     0.119861
# star         0.027501 -0.039222    -0.038432
# writer       1.000000 -0.021123    -0.021537
# year        -0.021123  1.000000     0.996846
# yearcorrect -0.021537  0.996846     1.000000

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# budget       budget         1.000000
#              company        0.157083
#              country        0.118863
#              director       0.011052
#              genre         -0.401052
#                               ...
# yearcorrect  score          0.119861
#              star          -0.038432
#              writer        -0.021537
#              year           0.996846
#              yearcorrect    1.000000
# Length: 225, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# genre        budget        -0.401052
# budget       genre         -0.401052
# genre        gross         -0.263051
# gross        genre         -0.263051
#              rating        -0.191666
#                               ...
# director     director       1.000000
# country      country        1.000000
# company      company        1.000000
# year         year           1.000000
# yearcorrect  yearcorrect    1.000000
# Length: 225, dtype: float64

# %%
# We can now take a look at the ones that have a high correlation (> 0.5)

high_corr = sorted_pairs[(sorted_pairs) > 0.5]

high_corr
# Out:
# gross        budget         0.682588
# budget       gross          0.682588
# yearcorrect  year           0.996846
# year         yearcorrect    0.996846
# released     year           0.996873
# year         released       0.996873
# released     yearcorrect    0.999434
# yearcorrect  released       0.999434
# budget       budget         1.000000
# rating       rating         1.000000
# writer       writer         1.000000
# star         star           1.000000
# score        score          1.000000
# runtime      runtime        1.000000
# released     released       1.000000
# name         name           1.000000
# gross        gross          1.000000
# genre        genre          1.000000
# director     director       1.000000
# country      country        1.000000
# company      company        1.000000
# year         year           1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
# Company has low correlation
